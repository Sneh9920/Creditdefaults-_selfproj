# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
# %matplotlib inline
from pylab import rcParams

# %%
df=pd.read_csv("/content/drive/MyDrive/credit.csv",header=1)
df.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...          0          0          0         0       689         0
# 1  ...       3272       3455       3261         0      1000      1000
# 2  ...      14331      14948      15549      1518      1500      1000
# 3  ...      28314      28959      29547      2000      2019      1200
# 4  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %%
df.isnull().sum()
# Out:
# ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default payment next month    0
# dtype: int64

# %%
df['default payment next month'].value_counts()
# Out:
# 0    23364
# 1     6636
# Name: default payment next month, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  int64
#  1   LIMIT_BAL                   30000 non-null  int64
#  2   SEX                         30000 non-null  int64
#  3   EDUCATION                   30000 non-null  int64
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_0                       30000 non-null  int64
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  int64
# ...

# %%
df.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# ...

# %%
df.corr()
# Out:
#                                   ID  LIMIT_BAL       SEX  EDUCATION  \
# ID                          1.000000   0.026179  0.018497   0.039177
# LIMIT_BAL                   0.026179   1.000000  0.024755  -0.219161
# SEX                         0.018497   0.024755  1.000000   0.014232
# EDUCATION                   0.039177  -0.219161  0.014232   1.000000
# MARRIAGE                   -0.029079  -0.108139 -0.031389  -0.143464
# AGE                         0.018678   0.144713 -0.090874   0.175061
# PAY_0                      -0.030575  -0.271214 -0.057643   0.105364
# PAY_2                      -0.011215  -0.296382 -0.070771   0.121566
# PAY_3                      -0.018494  -0.286123 -0.066096   0.114025
# PAY_4                      -0.002735  -0.267460 -0.060173   0.108793
# PAY_5                      -0.022199  -0.249411 -0.055064   0.097520
# PAY_6                      -0.020270  -0.235195 -0.044008   0.082316
# BILL_AMT1                   0.019389   0.285430 -0.033642   0.023581
# ...

# %% [markdown]
# EDA

# %%
sns.countplot('default payment next month', data= df)
# Create a Countplot of the Classes
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# Create a PairPlot of the Data with Seaborn, set Hue to SEX
sns.pairplot(data=df,    
            y_vars= ['LIMIT_BAL','SEX','EDUCATION','MARRIAGE','AGE'],
            x_vars= ['default payment next month'], hue = 'SEX')
plt.figure(figsize=(4,10))

# %%
plot = sns.heatmap(df.corr(), cmap="YlGnBu", annot=True)
plt.rcParams["figure.figsize"] = [30, 30]

# %%
# !pip install dtale
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 12.8 MB 3.1 MB/s
# ...
#      |████████████████████████████████| 9.5 MB 10.3 MB/s
# ...
#      |████████████████████████████████| 45 kB 4.1 MB/s
# ...
#      |████████████████████████████████| 40 kB 5.9 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 48.0 MB/s
# ...
#      |████████████████████████████████| 62 kB 915 kB/s
# ...
#      |████████████████████████████████| 79.9 MB 97 kB/s
# ...
#      |████████████████████████████████| 216 kB 41.7 MB/s
# ...
#      |████████████████████████████████| 9.8 MB 50.1 MB/s
# ...
#      |████████████████████████████████| 642 kB 52.0 MB/s
# ...
#      |████████████████████████████████| 357 kB 43.2 MB/s
# ...
#   Created wheel for dash-colorscales: filename=dash_colorscales-0.0.4-py3-none-any.whl size=62590 sha256=ff12e71b7f9ccaedcfd3f0edb5433f09f0b1fc53ba5c65fa95ba91a9fcc32382
# ...

# %%
import dtale

# %%
dtale.show(df)
# Out:
# http://cec765cd8855:40000/dtale/main/1

# %%
x=df.iloc[:,6:20]
y=df['default payment next month']

# %%
from imblearn.over_sampling import SMOTE
smote=SMOTE()
x_smote,y_smote=smote.fit_resample(x,y)

# %%
y_smote.value_counts()
# Out:
# 1    23364
# 0    23364
# Name: default payment next month, dtype: int64

# %% [markdown]
# Train Test Split

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x_smote,y_smote,test_size=0.2,random_state=0)

# %% [markdown]
# Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
logreg=LogisticRegression()
logreg.fit(x_train,y_train)
y_pred=logreg.predict(x_test)
print(metrics.classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.55      0.75      0.63      4613
#            1       0.62      0.39      0.48      4733
#
#     accuracy                           0.57      9346
#    macro avg       0.58      0.57      0.56      9346
# weighted avg       0.58      0.57      0.56      9346

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import AdaBoostClassifier

# %% [markdown]
# Decision Tree

# %%
DTC = DecisionTreeClassifier()
DTC.fit(x_train, y_train)
y_pred2 = DTC.predict(x_test)
print(metrics.classification_report(y_test, y_pred2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.72      0.75      4613
#            1       0.75      0.80      0.77      4733
#
#     accuracy                           0.76      9346
#    macro avg       0.76      0.76      0.76      9346
# weighted avg       0.76      0.76      0.76      9346

# %% [markdown]
# Randomforest

# %%
randomForest= RandomForestClassifier(n_estimators=1000)
randomForest.fit(x_train,y_train)
y_pred3 = randomForest.predict(x_test)
print(metrics.classification_report(y_test, y_pred3))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.86      0.85      4613
#            1       0.86      0.84      0.85      4733
#
#     accuracy                           0.85      9346
#    macro avg       0.85      0.85      0.85      9346
# weighted avg       0.85      0.85      0.85      9346

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(df.drop('default payment next month',axis=1))
scaled_features = scaler.fit_transform(df.drop('default payment next month',axis=1))
df_feat = pd.DataFrame(scaled_features,columns=df.columns[:-1])
df_feat.head()
# Out:
#          ID  LIMIT_BAL       SEX  EDUCATION  MARRIAGE       AGE     PAY_0  \
# 0 -1.731993  -1.136720  0.810161   0.185828 -1.057295 -1.246020  1.794564
# 1 -1.731878  -0.365981  0.810161   0.185828  0.858557 -1.029047 -0.874991
# 2 -1.731762  -0.597202  0.810161   0.185828  0.858557 -0.161156  0.014861
# 3 -1.731647  -0.905498  0.810161   0.185828 -1.057295  0.164303  0.014861
# 4 -1.731531  -0.905498 -1.234323   0.185828 -1.057295  2.334029 -0.874991
#
#       PAY_2     PAY_3     PAY_4  ...  BILL_AMT3  BILL_AMT4  BILL_AMT5  \
# 0  1.782348 -0.696663 -0.666599  ...  -0.667993  -0.672497  -0.663059
# 1  1.782348  0.138865  0.188746  ...  -0.639254  -0.621636  -0.606229
# 2  0.111736  0.138865  0.188746  ...  -0.482408  -0.449730  -0.417188
# 3  0.111736  0.138865  0.188746  ...   0.032846  -0.232373  -0.186729
# 4  0.111736 -0.696663  0.188746  ...  -0.161189  -0.346997  -0.348137
#
#    BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6
# ...

# %%
 x = df_feat
 y = df['default payment next month']
 from sklearn.model_selection import train_test_split
 x_train, x_test, y_train, y_test = train_test_split(x, y,stratify=y, test_size=0.3, random_state=101)
 from sklearn.ensemble import RandomForestClassifier
 rfc = RandomForestClassifier(n_estimators=200)
 rfc.fit(x_train,y_train)
 rfc_preds = rfc.predict(x_test)
 rfc_preds
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
import tensorflow as tf
df_feat.columns
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6'],
#       dtype='object')

# %%
ID = tf.feature_column.numeric_column("ID")
LIMIT_BAL = tf.feature_column.numeric_column("LIMIT_BAL")
SEX = tf.feature_column.numeric_column("SEX")
EDUCATION = tf.feature_column.numeric_column("EDUCATION")
MARRIAGE = tf.feature_column.numeric_column("MARRIAGE")
AGE = tf.feature_column.numeric_column("AGE")
PAY_0 = tf.feature_column.numeric_column("PAY_0")
PAY_2 = tf.feature_column.numeric_column("PAY_2")
PAY_3 = tf.feature_column.numeric_column("PAY_3")
PAY_4 = tf.feature_column.numeric_column("PAY_4")
PAY_5 = tf.feature_column.numeric_column("PAY_5")
PAY_6 = tf.feature_column.numeric_column("PAY_6")
BILL_AMT1 = tf.feature_column.numeric_column("BILL_AMT1")
BILL_AMT2 = tf.feature_column.numeric_column("BILL_AMT2")
BILL_AMT3 = tf.feature_column.numeric_column("BILL_AMT3")
BILL_AMT4 = tf.feature_column.numeric_column("BILL_AMT4")
BILL_AMT5 = tf.feature_column.numeric_column("BILL_AMT5")
BILL_AMT6 = tf.feature_column.numeric_column("BILL_AMT6")
PAY_AMT1 = tf.feature_column.numeric_column("PAY_AMT1")
PAY_AMT2 = tf.feature_column.numeric_column("PAY_AMT2")
PAY_AMT3 = tf.feature_column.numeric_column("PAY_AMT3")
PAY_AMT4 = tf.feature_column.numeric_column("PAY_AMT4")
PAY_AMT5 = tf.feature_column.numeric_column("PAY_AMT5")
PAY_AMT6 = tf.feature_column.numeric_column("PAY_AMT6")

# %%
feat_cols = ['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
       'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
       'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
       'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6']

# %%
classifier = tf.compat.v1.estimator.DNNClassifier(hidden_units = [10, 20, 10], n_classes = 2, feature_columns = feat_cols )
# Out:
# 2022-07-24 14:25:56,677 - INFO     - Using default config.
# 2022-07-24 14:25:56,680 - WARNING  - Using temporary folder as model directory: /tmp/tmprgkeuznw
# 2022-07-24 14:25:56,687 - INFO     - Using config: {'_model_dir': '/tmp/tmprgkeuznw', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# ...

# %%
input_func = tf.compat.v1.estimator.inputs.pandas_input_fn(x=x_train,y=y_train,batch_size=20,shuffle=True)

# %%
classifier.train(input_fn=input_func,steps=500)
# Out:
# 2022-07-24 14:25:57,064 - WARNING  - From /usr/local/lib/python3.7/dist-packages/tensorflow/python/training/training_util.py:397: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# 2022-07-24 14:25:57,235 - WARNING  - From /usr/local/lib/python3.7/dist-packages/tensorflow_estimator/python/estimator/inputs/queues/feeding_queue_runner.py:65: QueueRunner.__init__ (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# ...
